# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
ids = pd.read_csv("scale_data/scaledata/Dennis+Schwartz/id.Dennis+Schwartz.txt", sep="[\r\n]+", header=None, names=["id"])
label_3class = pd.read_csv("scale_data/scaledata/Dennis+Schwartz/label.3class.Dennis+Schwartz.txt", sep="[\r\n]+", names=["3class_label"])
label_4class = pd.read_csv("scale_data/scaledata/Dennis+Schwartz/label.4class.Dennis+Schwartz.txt", sep="[\r\n]+",names=["4class_label"])
rating = pd.read_csv("scale_data/scaledata/Dennis+Schwartz/rating.Dennis+Schwartz.txt", sep="[\r\n]+",names=["rating"])
subj = pd.read_csv("scale_data/scaledata/Dennis+Schwartz/subj.Dennis+Schwartz.txt", sep="[\r\n]+",names=["subj_extraction"])
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """

# %%
dennis = pd.concat([ids,label_3class, label_4class, rating, subj], axis = 1)

# %%
dennis.head(10)
# Out:
#       id  3class_label  4class_label  rating  \
# 0  29420             0             0     0.1
# 1  17219             0             0     0.2
# 2  18406             0             0     0.2
# 3  18648             0             0     0.2
# 4  20021             0             0     0.2
# 5  20454             0             0     0.2
# 6  20473             0             0     0.2
# 7  20538             0             0     0.2
# 8  21002             0             0     0.2
# 9  21739             0             0     0.2
#
#                                      subj_extraction
# 0  in my opinion , a movie reviewer's most import...
# 1  you can watch this movie , that is based on a ...
# 2  this is asking a lot to believe , and though i...
# 3  no heroes and no story are the main attributes...
# 4  this is not an art movie , yet i saw it an art...
# 5  a satirical film where warren beatty tries to ...
# 6  this sci-fi'er left a lot to be desired . it d...
# 7  this is a dull , unfunny film , lacking an edg...
# 8  instead he makes him an offer he can't very we...
# 9  vibrant culture . great people . thinking of h...

# %%
dennis["strongly neg"]=dennis.apply(lambda x:x["4class_label"]==0, axis=1)
dennis["neg"]=dennis.apply(lambda x:x["4class_label"]==1, axis=1)
dennis["pos"]=dennis.apply(lambda x:x["4class_label"]==2, axis=1)
dennis["strongly pos"]=dennis.apply(lambda x:x["4class_label"]==3, axis=1)

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(dennis, test_size=0.2)

# %%
train.head()
# Out:
#         id  3class_label  4class_label  rating  \
# 946  21199             2             3     0.8
# 843  24082             2             2     0.7
# 85   24840             0             0     0.3
# 314  28308             0             1     0.4
# 308  28013             0             1     0.4
#
#                                        subj_extraction  strongly neg    neg  \
# 946  the film critic , jonathan rosenbaum , has wri...         False  False
# 843  everyone knows how bad it is to be called a ch...         False  False
# 85   a modern day comedy taking place in havana , c...          True  False
# 314  this is an obscure bela lugosi film and it's n...         False   True
# 308  a sci-fi film , originally started as a studen...         False   True
#
#        pos  strongly pos
# 946  False          True
# 843   True         False
# 85   False         False
# 314  False         False
# 308  False         False

# %%
train["subj_extraction"][8]
# Out:
# 'instead he makes him an offer he can\'t very well refuse , stay with me and i\'ll give you everything you want . it all turns out to be a tedious game to see who is in control : brains or brawn . the kid plays his part like he\'s a lump of coal and the sex is so uninviting , making it seem just as boring as watching paint dry on a wall . and like all the characters in this film , is not developed . there is no rhyme or reason for all this sleaze to be taking place , except for making the audience into voyeurs , like the invalid . what is quickly resolved , is that glover isn\'t queer , just manipulaive and mentally sick . that explanation of him doesn\'t ring true , anyway , as he always has a blank and uninteresting look on his face , and nothing he does throughout the film is taking him to anything but a dead-end . so it becomes hard to feel anything for him , but pity and contempt . the sadistic games are better delivered now with the presence of helen , but the menage a trois doesn\'t have the nuances , wit , or actors to pull off the macabre effects it was trying desperately to get away with . it becomes obvious that glover has a death-wish and has been preparing all-the-time for this and now seems ready , as he reads from a poem by a zen monk who is about to die , which goes something like this-- " in all my 56-years alive , i\'ve seen no miracles . it is okay to die today . but even that attempt to get some life into the story fizzled , as the film just wound down trying to outsmart itself with shockers to its denouement , but ended up not being a very thrilling thriller or even living up to its reputation of being a controversial film . it was just a dull , exploitive movie , distinguished only by the fine performance of a good actor , pete postlethwaite , who was overwhelmed by being in such a trying film .'

# %%
train.shape
# Out:
# (821, 9)

# %%
import re, string
re_tok = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
def tokenize(s): 
    return re_tok.sub(r' \1 ', s).split()

# %%
tfidf = TfidfVectorizer(ngram_range=(1,3), tokenizer=tokenize, stop_words="english", strip_accents='unicode', use_idf=True,
               smooth_idf=True, sublinear_tf=True)

# %%
x = tfidf.fit_transform(train["subj_extraction"])
test_vec = tfidf.transform(test["subj_extraction"])

# %%
def pr(y_i, y):
    p = x[y==y_i].sum(0)
    return (p+1) / ((y==y_i).sum()+1)

# %%
def get_mdl(y):
    y = y.values
    r = np.log(pr(1,y) / pr(0,y))
    m = LogisticRegression(C=4, dual=True)
    x_nb = x.multiply(r)
    return m.fit(x_nb, y), r

# %%
preds = np.zeros((test.shape[0], 4))

for i, j in enumerate(["strongly neg","neg","pos","strongly pos"]):
    m,r = get_mdl(train[j])
    preds[:,i] = m.predict_proba(test_vec.multiply(r))[:,1]

# %%
preds
# Out:
# array([[ 0.10931476,  0.41027306,  0.28207832,  0.06892893],
#        [ 0.13770649,  0.3932625 ,  0.32138913,  0.05511698],
#        [ 0.10271261,  0.41561532,  0.30533183,  0.04377082],
#        [ 0.08285673,  0.42706208,  0.33575238,  0.03985275],
#        [ 0.09364587,  0.42968696,  0.2487385 ,  0.04073993],
#        [ 0.13576145,  0.40772985,  0.34452329,  0.09776425],
#        [ 0.14411228,  0.4134449 ,  0.26157067,  0.04708683],
#        [ 0.0910279 ,  0.41251933,  0.29620693,  0.0384327 ],
#        [ 0.08219978,  0.40684527,  0.26019244,  0.05302534],
#        [ 0.11039718,  0.39571967,  0.29160962,  0.04770335],
#        [ 0.09435631,  0.43722036,  0.32407648,  0.07167701],
#        [ 0.08082152,  0.40783737,  0.30475508,  0.07144997],
#        [ 0.05988391,  0.47655855,  0.18629143,  0.02654458],
#        [ 0.14215829,  0.42006043,  0.29977753,  0.04892364],
#        [ 0.08379988,  0.40572724,  0.34059374,  0.05765979],
#        [ 0.06958399,  0.39160217,  0.36593131,  0.05228533],
#        [ 0.08801907,  0.4085152 ,  0.30395888,  0.05979838],
#        [ 0.14225076,  0.409669  ,  0.26388733,  0.06116681],
#        [ 0.10240513,  0.40611405,  0.26731315,  0.14736465],
#        [ 0.15579643,  0.43413567,  0.29965501,  0.05617706],
#        [ 0.12635802,  0.41050576,  0.26490363,  0.05091708],
#        [ 0.16879088,  0.41158996,  0.26359385,  0.04601469]])

# %%
test.head(100)
# Out:
#          id  3class_label  4class_label  rating  \
# 431   22908             1             1     0.5
# 890   28342             2             2     0.7
# 505   26675             1             1     0.5
# 847   24597             2             2     0.7
# 542   27872             1             1     0.5
# 927   18307             2             3     0.8
# 128   28199             0             0     0.3
# 511   26830             1             1     0.5
# 670   23614             1             2     0.6
# 746   28301             1             2     0.6
# 721   27022             1             2     0.6
# 934   19673             2             3     0.8
# 498   26063             1             1     0.5
# 446   23932             1             1     0.5
# 415   22171             1             1     0.5
# 726   27128             1             2     0.6
# 994   29425             2             3     0.8
# 111   26654             0             0     0.3
# 954   22250             2             3     0.8
# 564   28537             1             1     0.5
# 49    20332             0             0     0.3
# 80    24237             0             0     0.3
# 36    17255             0             0     0.3
# 539   27839             1             1     0.5
# 225   23058             0             1     0.4
# 256   24955             0             1     0.4
# 711   26850             1             2     0.6
# 873   27130             2             2     0.7
# 710   26832             1             2     0.6
# 592   29409             1             1     0.5
# ...     ...           ...           ...     ...
# 914   17145             2             3     0.8
# 375   18016             1             1     0.5
# 648   20597             1             2     0.6
# 559   28334             1             1     0.5
# 884   28226             2             2     0.7
# 327   28599             0             1     0.4
# 155   29137             0             0     0.3
# 96    25580             0             0     0.3
# 668   23494             1             2     0.6
# 734   27515             1             2     0.6
# 265   25430             0             1     0.4
# 113   27016             0             0     0.3
# 434   23154             1             1     0.5
# 390   19908             1             1     0.5
# 245   24600             0             1     0.4
# 282   26651             0             1     0.4
# 77    24135             0             0     0.3
# 298   27484             0             1     0.4
# 246   24651             0             1     0.4
# 485   25578             1             1     0.5
# 172   17300             0             1     0.4
# 29    28418             0             0     0.2
# 150   28961             0             0     0.3
# 210   21898             0             1     0.4
# 532   27617             1             1     0.5
# 883   28204             2             2     0.7
# 1022  26256             2             3     0.9
# 1008  18480             2             3     0.9
# 156   29139             0             0     0.3
# 94    25326             0             0     0.3
#
#                                         subj_extraction  strongly neg    neg  \
# 431   a minor noir film , originally made for radio ...         False   True
# 890   love's a bitch is an intricate film noir tale ...         False  False
# 505   inspired by a pushkin novel , which it conside...         False   True
# 847   taxman is a wonderfully played cynical , offbe...         False  False
# 542   it plays more like a theatrical ghost story or...         False   True
# 927   this is a come to your own conclusion movie , ...         False  False
# 128   a film that could have been an interesting stu...          True  False
# 511   director-writer andrew l . stone keeps the ter...         False   True
# 670   a more-than-acceptable variation of jacques to...         False  False
# 746   a road film about trying to reach somewhere . ...         False  False
# 721   a steamy noir for its time , featuring the sul...         False  False
# 934   all the sounds heard in the cell are the ones ...         False  False
# 498   these misguided adventures are things a kid ne...         False   True
# 446   a feel-good , old-fashioned ( except for all t...         False   True
# 415   a very troubling film , regarding the crimes o...         False   True
# 726   honestly . spoiler in the next paragraph . the...         False  False
# 994   a top-notch film noir about the loneliness and...         False  False
# 111   this parody of other gangster films suffers fr...          True  False
# 954   the often filmed story of joan of arc , but a ...         False  False
# 564   the energy and vitality of these musical score...         False   True
# 49    celebrity is like an amalgam of old woody alle...          True  False
# 80    high fidelity ( director : stephen frears ; sc...          True  False
# 36    she doesn't love me . but even these words don...          True  False
# 539   zhang yang's bittersweet dramatic comedy , " s...         False   True
# 225   " open your eyes " asks a lot of questions , s...         False   True
# 256   a routine aip action-packed ww11 drama of hero...         False   True
# 711   a solid noir melodrama from vincent sherman , ...         False  False
# 873   an iconoclastic biopic about the adventurous 1...         False  False
# 710   kluger is perceived as being tougher and smart...         False  False
# 592   the crime caper was too absurd and trite to ca...         False   True
# ...                                                 ...           ...    ...
# 914   can you imagine that this innovative , creativ...         False  False
# 375   it is filmed with calm detachment , in black-a...         False   True
# 648   the children , despite their discontentments w...         False  False
# 559   it's a gritty cop movie when the two protagoni...         False   True
# 884   the action takes place offscreen . some viwers...         False  False
# 327   a slickly done , very depressive melodrama abo...         False   True
# 155   this was one of the poorer charlie chan episod...          True  False
# 96    " tea with mussolini " is based on the semiaut...          True  False
# 668   the film highlights the interactions of the li...         False  False
# 734   the first thing you should be aware of about t...         False  False
# 265   this disney presentation of a time travel fant...         False   True
# 113   the same old romantic comedy formula story tha...          True  False
# 434   is presented onscreen is an intelligent but so...         False   True
# 390   there was no visible difference between the ch...         False   True
# 245   she acts and looks a lot like gwyneth paltrow ...         False   True
# 282   the film's subject is the search for ideal lov...         False   True
# 77    unfortunately , in this ridiculous remake , th...          True  False
# 298   a made for tv movie that looks and feels like ...         False   True
# 246   there are no surprises in this oater , but it'...         False   True
# 485   this scorsese " mean streets " type of film ha...         False   True
# 172   though , i gladly admit , i enjoyed viewing th...         False   True
# 29    there's slim pickings in this shamelessly cont...          True  False
# 150   a film that means well , but is too pushy in p...          True  False
# 210   it also puts him in a depressed mood , as he s...         False   True
# 532   it is hard for me to believe that one of the w...         False   True
# 883   art biopics are rarely successful ventures but...         False  False
# 1022  this neglected low-budget b/w noir film from t...         False  False
# 1008  he is of such a good nature , that he can't st...         False  False
# 156   this b-film , directed by samuel fuller , is o...          True  False
# 94    a farcical political drama , done in the manne...          True  False
#
#         pos  strongly pos
# 431   False         False
# 890    True         False
# 505   False         False
# 847    True         False
# 542   False         False
# 927   False          True
# 128   False         False
# 511   False         False
# 670    True         False
# 746    True         False
# 721    True         False
# 934   False          True
# 498   False         False
# 446   False         False
# 415   False         False
# 726    True         False
# 994   False          True
# 111   False         False
# 954   False          True
# 564   False         False
# 49    False         False
# 80    False         False
# 36    False         False
# 539   False         False
# 225   False         False
# 256   False         False
# 711    True         False
# 873    True         False
# 710    True         False
# 592   False         False
# ...     ...           ...
# 914   False          True
# 375   False         False
# 648    True         False
# 559   False         False
# 884    True         False
# 327   False         False
# 155   False         False
# 96    False         False
# 668    True         False
# 734    True         False
# 265   False         False
# 113   False         False
# 434   False         False
# 390   False         False
# 245   False         False
# 282   False         False
# 77    False         False
# 298   False         False
# 246   False         False
# 485   False         False
# 172   False         False
# 29    False         False
# 150   False         False
# 210   False         False
# 532   False         False
# 883    True         False
# 1022  False          True
# 1008  False          True
# 156   False         False
# 94    False         False
#
# [100 rows x 9 columns]
