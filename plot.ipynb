# %%
import matplotlib.pyplot as plt

# %%
LOST = [0.69, 0.6854, 0.6813, 0.6773, 0.7, 0.6695, 0.6658, 0.6623, 0.6589, 0.6556]
ACC_TRAIN = [ 0.6978, 0.7032 , 0.7032, 0.7032,  0.700, 0.7032 , 0.7032 , 0.7032, 0.7032 , 0.7032]
ACC_TEST =[0.7027, 0.7027, 0.7027, 0.7027, 0.7027,0.7027, 0.7027, 0.7027, 0.7027, 0.7027]

# %%
LOST = [0.6486,0.6430,0.6378,0.6328,0.6280, 0.6232,0.6185,0.6140,0.6097,0.6055]
ACC_TRAIN = [0.7379]*10
ACC_TEST =[0.7401]*10

# %%
plt.subplot(1, 2, 1)
x_component = [i for i in range(len(LOST))]
plt.plot(x_component, LOST)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.subplot(1, 2, 2)
plt.plot(x_component, ACC_TRAIN, label = 'train accuracy')
plt.plot(x_component, ACC_TEST, label = 'test accuracy')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
